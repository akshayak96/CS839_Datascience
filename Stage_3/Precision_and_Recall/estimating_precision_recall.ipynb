# %% [markdown]
# # Prep 1: steps to install the packages

# %%
# !pip install py_entitymatching
# !pip install scipy
# !pip install numpy
# !pip install pandas
# Out:
# Requirement already satisfied: py_entitymatching in /usr/local/lib/python2.7/dist-packages (0.3.1)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python2.7/dist-packages (from py_entitymatching) (2.4.0)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python2.7/dist-packages (from py_entitymatching) (0.20.3)
# Requirement already satisfied: pandas-profiling>=1.4.0 in /usr/local/lib/python2.7/dist-packages (from py_entitymatching) (1.4.1)
# Requirement already satisfied: cloudpickle>=0.2.1 in /usr/local/lib/python2.7/dist-packages (from py_entitymatching) (0.6.1)
# Requirement already satisfied: py-stringsimjoin==0.3.0 in /usr/local/lib/python2.7/dist-packages (from py_entitymatching) (0.3.0)
# Requirement already satisfied: PyPrind in /usr/local/lib/python2.7/dist-packages (from py_entitymatching) (2.11.2)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python2.7/dist-packages (from scikit-learn>=0.18->py_entitymatching) (1.2.1)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python2.7/dist-packages (from scikit-learn>=0.18->py_entitymatching) (1.16.3)
# Requirement already satisfied: jinja2>=2.8 in /usr/local/lib/python2.7/dist-packages (from pandas-profiling>=1.4.0->py_entitymatching) (2.10.1)
# Requirement already satisfied: matplotlib>=1.4 in /usr/local/lib/python2.7/dist-packages (from pandas-profiling>=1.4.0->py_entitymatching) (2.2.4)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python2.7/dist-packages (from pandas-profiling>=1.4.0->py_entitymatching) (0.24.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python2.7/dist-packages (from pandas-profiling>=1.4.0->py_entitymatching) (1.12.0)
# Requirement already satisfied: py-stringmatching>=0.2.1 in /usr/local/lib/python2.7/dist-packages (from py-stringsimjoin==0.3.0->py_entitymatching) (0.4.1)
# Requirement already satisfied: joblib in /usr/local/lib/python2.7/dist-packages (from py-stringsimjoin==0.3.0->py_entitymatching) (0.12.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python2.7/dist-packages (from jinja2>=2.8->pandas-profiling>=1.4.0->py_entitymatching) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python2.7/dist-packages (from matplotlib>=1.4->pandas-profiling>=1.4.0->py_entitymatching) (0.10.0)
# Requirement already satisfied: backports.functools-lru-cache in /usr/local/lib/python2.7/dist-packages (from matplotlib>=1.4->pandas-profiling>=1.4.0->py_entitymatching) (1.5)
# Requirement already satisfied: subprocess32 in /usr/local/lib/python2.7/dist-packages (from matplotlib>=1.4->pandas-profiling>=1.4.0->py_entitymatching) (3.5.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python2.7/dist-packages (from matplotlib>=1.4->pandas-profiling>=1.4.0->py_entitymatching) (1.1.0)
# Requirement already satisfied: pytz in /usr/local/lib/python2.7/dist-packages (from matplotlib>=1.4->pandas-profiling>=1.4.0->py_entitymatching) (2018.9)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python2.7/dist-packages (from matplotlib>=1.4->pandas-profiling>=1.4.0->py_entitymatching) (2.5.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python2.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=1.4->pandas-profiling>=1.4.0->py_entitymatching) (41.0.1)
# Requirement already satisfied: scipy in /usr/local/lib/python2.7/dist-packages (1.2.1)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python2.7/dist-packages (from scipy) (1.16.3)
# Requirement already satisfied: numpy in /usr/local/lib/python2.7/dist-packages (1.16.3)
# Requirement already satisfied: pandas in /usr/local/lib/python2.7/dist-packages (0.24.2)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python2.7/dist-packages (from pandas) (1.16.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python2.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python2.7/dist-packages (from pandas) (2.5.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python2.7/dist-packages (from python-dateutil>=2.5.0->pandas) (1.12.0)

# %%
#from google.colab import files
#uploaded = files.upload()

# %% [markdown]
# # [NEED MODIFICATION: Modify this cell to point to the file location]
# # Prep 2: enter the file location on your harddisk

# %%
table_a = 'IMDB.csv'
table_b = 'Metacritic.csv'
candidate_set = 'Job_Movie_apply_rules_ds.csv'
prediction_set = 'apply_classifier_1.csv'

# %% [markdown]
# # Prep 3: reading the files into pandas dataframe

# %%
import pandas as pd

dfa = pd.read_csv(table_a)
dfb = pd.read_csv(table_b)
dfc = pd.read_csv(candidate_set)
dfp = pd.read_csv(prediction_set)

# %% [markdown]
# # Module: debug_blocker
# # Description: debug the blocking rule using the below script to ensure you are not dropping true matches
# # Note: You need to run Prep 1 and 2 in order to run this

# %%
# Example input format:
# Format of table_a:
# _id, attribute1, attribute2, ....., attributen

# Format of table_b:
# _id, attribute1, attribute2, ....., attributen

# Format of candidate_set
# A_id,B_id
# where A_id is _id from table_a and B_id is the _id column value from table_b

# %%
import py_entitymatching as em

def run_debug_blocker(table_a, table_b, table_a_key, table_b_key, candidate_set):
    dfl = em.read_csv_metadata(table_a, key=table_a_key)
    dfr = em.read_csv_metadata(table_b, key=table_b_key)

    # reading the candidate set and adding key
    dfcand = pd.read_csv(candidate_set)
    dfcand.drop_duplicates(inplace=True)
    dfcand.to_csv('cand_set_with_index.csv', index_label='id')

    dfcset = em.read_csv_metadata('cand_set_with_index.csv', key='id', ltable=dfl, 
                                  rtable=dfr, fk_ltable='A_id', fk_rtable='B_id')

    # running debug blocker to identify the records in A x B \ C
    debug_file = em.debug_blocker(dfcset, dfl, dfr)
    
    return debug_file

# %%
debug_file = run_debug_blocker(table_a, table_b, '_id', '_id', candidate_set)
# Out:
# No handlers could be found for logger "py_entitymatching.io.parsers"

# %%
debug_file
# Out:
#      _id  ltable__id  rtable__id  \
# 0      0         687        1521
# 1      1        1879         383
# 2      2        1348         991
# 3      3        1998        1669
# 4      4        3150        1224
# 5      5        2547        2909
# 6      6        1235        1558
# 7      7         666         736
# 8      8        2397        2614
# 9      9        1875        2983
# 10    10        1099        1580
# 11    11         275         540
# 12    12         266         624
# 13    13         275         801
# 14    14         808        2127
# 15    15        2801         632
# 16    16         122        1034
# 17    17        3156         905
# 18    18        2134        2183
# 19    19        2602        1446
# 20    20        1981        1849
# 21    21        2984        1830
# 22    22         266        1260
# 23    23        2644        2723
# 24    24        1981        2183
# 25    25        1065        2921
# 26    26        1602        2286
# 27    27        3241         708
# 28    28        2024         175
# 29    29        3076        2986
# ..   ...         ...         ...
# 170  170        3107         590
# 171  171        3192        2111
# 172  172        3107        1511
# 173  173        2356        3090
# 174  174         666        2942
# 175  175         925         736
# 176  176        2924        2830
# 177  177         501        1910
# 178  178         628         650
# 179  179        2414        1676
# 180  180        3107        1278
# 181  181        1663        1521
# 182  182        3107        1034
# 183  183        2817         905
# 184  184        2383         152
# 185  185         559          27
# 186  186        3095        1975
# 187  187        1327        3032
# 188  188         277        2617
# 189  189         288         491
# 190  190        2654        2188
# 191  191         583        1156
# 192  192        1524        1925
# 193  193         942         383
# 194  194        1538        2654
# 195  195        2312        2983
# 196  196        1257         502
# 197  197         278        3033
# 198  198         209        3033
# 199  199        2837        2338
#
#                                         ltable_title  ltable_release_year  \
# 0                                   The Exorcist III                 1990
# 1                                       Tom and Huck                 1995
# 2                                          Zoolander                 2001
# 3                                  Empire of the Sun                 1987
# 4                                            Syriana                 2005
# 5              The Lord of the Rings: The Two Towers                 2002
# 6                                            Super 8                 2011
# 7                                      Boogie Nights                 1997
# 8                                    Man on the Moon                 1999
# 9                                   The Flamingo Kid                 1984
# 10                                     Runaway Bride                 1999
# 11                                       The Sandlot                 1993
# 12                                       The Pianist                 2002
# 13                                       The Sandlot                 1993
# 14                           The Wolf of Wall Street                 2013
# 15                                        Black Mass                 2015
# 16                                 Anna and the King                 1999
# 17                                     The Hurricane                 1999
# 18                                         Pinocchio                 1940
# 19                                             Shrek                 2001
# 20                                  License to Drive                 1988
# 21                                    Romeo Must Die                 2000
# 22                                       The Pianist                 2002
# 23                                    Doctor Strange                 2016
# 24                                  License to Drive                 1988
# 25                                      The Waterboy                 1998
# 26                                          Chocolat                 2000
# 27                          Kubo and the Two Strings                 2016
# 28   Master and Commander: The Far Side of the World                 2003
# 29                                 Life of the Party                 2018
# ..                                               ...                  ...
# 170                                      King Arthur                 2004
# 171                                   Racing Stripes                 2005
# 172                                      King Arthur                 2004
# 173                      Dragon: The Bruce Lee Story                 1993
# 174                                    Boogie Nights                 1997
# 175                                            Bambi                 1942
# 176                                Life Is Beautiful                 1997
# 177                            The Last Picture Show                 1971
# 178                                      The Missing                 2003
# 179                                        Alexander                 2004
# 180                                      King Arthur                 2004
# 181              The House with a Clock in Its Walls                 2018
# 182                                      King Arthur                 2004
# 183                                   Cinderella Man                 2005
# 184                                    Take the Lead                 2006
# 185                                        Abduction                 2011
# 186                                            Radio                 2003
# 187                                        Manhattan                 1979
# 188                              Rumble in the Bronx                 1995
# 189                             The Age of Innocence                 1993
# 190                          The Fate of the Furious                 2017
# 191                                       The Switch                 2010
# 192                                       Barbershop                 2002
# 193               Journey to the Center of the Earth                 2008
# 194                         The Last of the Mohicans                 1992
# 195                         The Theory of Everything                 2014
# 196                                 Dan in Real Life                 2007
# 197                               500 Days of Summer                 2009
# 198                               Autumn in New York                 2000
# 199                                    Fantasia 2000                 1999
#
#      ltable_movie_rating  \
# 0                    6.3
# 1                    5.6
# 2                    6.6
# 3                    7.8
# 4                    6.9
# 5                    8.7
# 6                    7.0
# 7                    7.9
# 8                    7.4
# 9                    6.2
# 10                   5.5
# 11                   7.8
# 12                   8.5
# 13                   7.8
# 14                   8.2
# 15                   6.9
# 16                   6.7
# 17                   7.6
# 18                   7.5
# 19                   7.9
# 20                   6.3
# 21                   6.1
# 22                   8.5
# 23                   7.5
# 24                   6.3
# 25                   6.1
# 26                   7.3
# 27                   7.8
# 28                   7.4
# 29                   5.5
# ..                   ...
# 170                  6.3
# 171                  5.2
# 172                  6.3
# 173                  7.0
# 174                  7.9
# 186               CM                                  Stand and Deliver
# 187               CM                                 All the Real Girls
# 188               CM                                       A Bronx Tale
# 189               CM                                 Breaking the Waves
# 190               CM                                          One of Us
# 191               CM                                             Capote
# 192               CM                                             Hukkle
# 193               CM                                    Song of the Sea
# 194               CM           Jung (War) in the Land of the Mujaheddin
# 195               CM                                         The Circus
# 196               CM                                          Innocence
# 197               CM                                            Tadpole
# 198               CM                                            Tadpole
# 199               CM                                           Fantasia
#
#     rtable_release_year rtable_movie_rating  \
# 0                  2004                 7.4
# 1                  2014                 8.3
# 2                  2001                 6.6
# 3                  1963                 9.1
# 4                  2002                 7.5
# 5                  2001                 9.1
# 6                  2002                 7.4
# 7                  2004                 tbd
# 8                  2004                 8.0
# 9                  1929                 tbd
# 10                 2004                 8.0
# 11                 2012                 6.0
# 12                 2002                 8.8
# 13                 2005                 7.6
# 14                 2004                 8.9
# 15                 2015                 8.4
# 16                 1999                 8.9
# 17                 1999                 8.8
# 18                 2010                 8.1
# 19                 1972                 tbd
# 20                 2013                 tbd
# 21                 1984                 tbd
# 22                 2006                 8.3
# 23                 2007                 tbd
# 24                 2010                 8.1
# 25                 1979                 8.8
# 26                 2000                 8.4
# 27                 1996                 8.5
# 28                 1992                 8.3
# 29                 2018                 7.1
# ..                  ...                 ...
# 170                2003                 7.3
# 171                2012                 7.6
# 172                2006                 7.8
# 173                2000                 tbd
# 174                1942                 8.0
# 175                2004                 tbd
# 176                1991                 tbd
# 177                1993                 8.2
# 178                2000                 7.5
# 179                2002                 7.7
# 180                1997                 8.6
# 181                2004                 7.4
# 182                1999                 8.9
# 183                1999                 8.8
# 184                1998                 8.4
# 185                2002                 7.3
# 186                1988                 tbd
# 187                2003                 6.7
# 188                1993                 8.7
# 189                1996                 8.1
# 190                2017                 7.7
# 191                2005                 7.8
# 192                2003                 7.7
# 193                2014                 8.3
# 194                2001                 tbd
# 195                1929                 tbd
# 196                2001                 8.2
# 197                2002                 tbd
# 198                2002                 tbd
# 199                1940                 8.0
#
#                                                                                           rtable_summary  \
# 0    The story of a young father forging a relationship with his handicapped son, whom he meets for t...
# 1    Ben and his little sister Saoirse, the last Seal-child, embark on a fantastic journey across a f...
# 2    A spiraling descent into fear and the perils of relationships in the tradition of Hitchcock. (Mi...
# 3    Allied prisoners of war plan for several hundred of their number to escape from a German camp du...
# 4                                An epic story of a Japanese teenager's life in the age of the Internet.
# 5    An epic adventure of good against evil, a story of the power of friendship and individual courag...
# 6                              Chronicles the life and events of 28 New Yorkers during the week of 9/11.
# 7    Shot entirely in Morocco and Marrakech, Raja is the story of a beautiful young Moroccan woman li...
# 8                                                                                 The title says it all.
# 9                                           The Tramp finds work and the girl of his dreams at a circus.
# 10   A documentary about the tragedy of the Israeli occupation, focusing on an alternative education ...
# 11   Set in the world of male strippers, "Magic Mike" follows Mike as he takes a young dancer called ...
# 12   The story of Danny Balint, who transformed himself from Jewish religious student to a rising sta...
# 13   Set in the 1930's, Gilles' Wife is a haunting tale of love and betrayal in a small mining town o...
# 14   Based on true events from the civil war in Rwanda, this film profiles Paul Rusesabagina (Don Che...
# 15   A captivating look behind the scenes of the remarkable life of a young Swedish girl who became o...
# 6                 CM
# 7                 CM
# 8                 CM
# 9                 CM
# 10                CM
# 11                CM
# 12                CM
# 13                CM
# 14                CM
# 15                CM
# 16                CM
# 17                CM
# 18                CM
# 19                CM
# 20                CM
# 21                CM
# 22                CM
# 23                CM
# 24                CM
# 25                CM
# 26                CM
# 27                CM
# 28                CM
# 29                CM
# ..               ...
# 170               CM
# 171               CM
# 172               CM
# 173               CM
# 174               CM
# 175               CM
# 176               CM
# 177               CM
# 178               CM
# 179               CM
# 180               CM
# 181               CM
# 182               CM
# 183               CM
# 184               CM
# 185               CM
# 186               CM
# 187               CM
# 188               CM
# 189               CM
# 190               CM
# 191               CM
# 192               CM
# 193               CM
# 194               CM
# 195               CM
# 196               CM
# 197               CM
# 198               CM
# 199               CM
#
# [200 rows x 13 columns]

# %% [markdown]
# # Module: estimate_precision_recall
# # Description: the below code helps you get an estimation of P/R on the candidate set.

# %%
import pandas as pd
from scipy.stats import norm
from numpy import sqrt

delta = .05
Z = norm.ppf(1 - (delta / 2))

def estimate_PR(labeled_pairs, reduced_cands, predicted_matches):
    '''
    labeled_pairs - a pandas dataframe with schema id1,id2,label
                    Note label needs to be Boolean

    reduced_cands - a pandas dataframe with schema id1,id2
    predicted_matches - a pandas dataframe with schema id1,id2
    
    return:
        ( (recall lower bound, recall upper bound), (precision lower bound, precision upper bound) )
    '''

    labeled_pairs.drop_duplicates(inplace=True)
    labeled_pairs.columns = ['id1', 'id2', 'label']
    reduced_cands.columns = ['id1', 'id2']
    reduced_cand_set = set(zip(reduced_cands.id1, reduced_cands.id2))
    predicted_matches = set(zip(predicted_matches.id1, predicted_matches.id2))
    
    # estimate the recall
    # number of positives in the labeled sample
    actual_pos = float(labeled_pairs.label.sum())
    # the maximum number of postives in the candidate set
    max_actual_pos = float(actual_pos + len(reduced_cand_set) - len(labeled_pairs))
    
    # true positives in the labeled sample
    true_pos = float(labeled_pairs.apply(lambda x : (x['id1'], x['id2']) in predicted_matches and x['label'], axis=1).sum())
    #estimated recall
    recall = float(true_pos / actual_pos)

    recall_error = Z * sqrt( ((recall * (1 - recall)) / (actual_pos)) * ((max_actual_pos - actual_pos) / (max_actual_pos - 1)) )


    # estimate Precision
    labeled_set  = set(zip(labeled_pairs.id1, labeled_pairs.id2))
    predicted_pos = float(len(labeled_set & predicted_matches))
    
    predicted_pos_in_reduced_cand_set = float(len(reduced_cand_set & predicted_matches))
    
    alpha =  predicted_pos_in_reduced_cand_set / len(predicted_matches)
    precision = alpha * (true_pos / predicted_pos)
    
    precision_error = alpha * Z * sqrt( ((precision * (1 - precision)) / predicted_pos) * (float((len(predicted_matches) - predicted_pos)) / (len(predicted_matches)  - 1)) )

    return ((recall - recall_error, recall + recall_error),
            (precision - precision_error, precision + precision_error))

# %% [markdown]
# # [NEED MODIFICATION: Modify this cell to point to the file location]

# %%
# read the labeled pairs file, i.e. the file with the labels
labeled_pairs = pd.read_csv('labeled.csv')[:400]
print(estimate_PR(labeled_pairs, dfc, dfp))
# Out:
# ((1.0, 1.0), (0.9722216822159181, 0.9869619912534696))

# %% [markdown]
# # Alternatively if you run into issues running this script on your laptop you can use
# # https://colab.research.google.com/notebooks/welcome.ipynb
