# %%
import pandas as pd
import csv

a = pd.read_csv('IMDB.csv')
b = pd.read_csv('Metacritic.csv')
c = pd.read_csv('Job_Movie_apply_rules_ds.csv')

s = c.sample(50)
n = 0
i = 1

for index, row in s.iterrows():
  print("============ " + str(i))
  print(a.iloc[int(row['A_id'])])
  print(b.iloc[int(row['B_id'])])
  inp = input("1 for yes, 2 for no: ")
  print(inp)
  if str(inp).strip() == "1":
    n += 1
  i += 1
    
print(n)
print(n/50)
# Out:
# ============ 1
# _id                                                          1483
# title                                      The Cabin in the Woods
# release_year                                                 2011
# movie_rating                                                    7
# summary         Five friends go for a break at a remote cabin,...
# Up_System                                                      CM
# Name: 1483, dtype: object
# _id                                                           555
# title                                      The Cabin in the Woods
# release_year                                                 2012
# movie_rating                                                  8.1
# summary         Five friends go to a remote cabin in the woods...
# Up_System                                                      CM
# Name: 555, dtype: object
# 1 for yes, 2 for no: 1
# 1
# ============ 2
# ...

# %%
print(n*1.0/50)
# Out:
# 0.8
